# %% [markdown]
# # Reading and overviewing data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
dataFrame = pd.read_csv(r"/content/application_record.csv")

# %%
dataFrame.head(20)
# Out:
#          ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0   5008804           M            Y               Y             0
# 1   5008805           M            Y               Y             0
# 2   5008806           M            Y               Y             0
# 3   5008808           F            N               Y             0
# 4   5008809           F            N               Y             0
# 5   5008810           F            N               Y             0
# 6   5008811           F            N               Y             0
# 7   5008812           F            N               Y             0
# 8   5008813           F            N               Y             0
# 9   5008814           F            N               Y             0
# 10  5008815           M            Y               Y             0
# 11  5112956           M            Y               Y             0
# 12  6153651           M            Y               Y             0
# ...

# %%
dataFrame2 = pd.read_csv(r"/content/credit_record.csv")

# %%
dataFrame2.head(20)
#months balance:-1=past month's data
#status:0=1 month overdue,5=bad debts more than 150 days,c=paid off that month,x=no loan for the month
# Out:
#          ID  MONTHS_BALANCE STATUS
# 0   5001711               0      X
# 1   5001711              -1      0
# 2   5001711              -2      0
# 3   5001711              -3      0
# 4   5001712               0      C
# 5   5001712              -1      C
# 6   5001712              -2      C
# 7   5001712              -3      C
# 8   5001712              -4      C
# 9   5001712              -5      C
# 10  5001712              -6      C
# 11  5001712              -7      C
# 12  5001712              -8      C
# 13  5001712              -9      0
# 14  5001712             -10      0
# 15  5001712             -11      0
# 16  5001712             -12      0
# 17  5001712             -13      0
# 18  5001712             -14      0
# 19  5001712             -15      0

# %%
dataFrame.isnull().sum()
# Out:
# ID                          0
# CODE_GENDER                 0
# FLAG_OWN_CAR                0
# FLAG_OWN_REALTY             0
# CNT_CHILDREN                0
# AMT_INCOME_TOTAL            0
# NAME_INCOME_TYPE            0
# NAME_EDUCATION_TYPE         0
# NAME_FAMILY_STATUS          0
# NAME_HOUSING_TYPE           0
# DAYS_BIRTH                  0
# DAYS_EMPLOYED               0
# FLAG_MOBIL                  0
# FLAG_WORK_PHONE             0
# FLAG_PHONE                  0
# FLAG_EMAIL                  0
# OCCUPATION_TYPE        134203
# CNT_FAM_MEMBERS             0
# dtype: int64

# %%
dataFrame2.isnull().sum()
# Out:
# ID                0
# MONTHS_BALANCE    0
# STATUS            0
# dtype: int64

# %%
dataFrame2['STATUS'].value_counts()["1"]
# Out:
# 11090

# %%
len(dataFrame2)
# Out:
# 1048575

# %%
len(dataFrame)
# Out:
# 438557

# %%
dataFrame.describe()
#19 children?
#365243 days of employment?
# Out:
#                  ID   CNT_CHILDREN  AMT_INCOME_TOTAL     DAYS_BIRTH  \
# count  4.385570e+05  438557.000000      4.385570e+05  438557.000000
# mean   6.022176e+06       0.427390      1.875243e+05  -15997.904649
# std    5.716370e+05       0.724882      1.100869e+05    4185.030007
# min    5.008804e+06       0.000000      2.610000e+04  -25201.000000
# 25%    5.609375e+06       0.000000      1.215000e+05  -19483.000000
# 50%    6.047745e+06       0.000000      1.607805e+05  -15630.000000
# 75%    6.456971e+06       1.000000      2.250000e+05  -12514.000000
# max    7.999952e+06      19.000000      6.750000e+06   -7489.000000
#
#        DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE     FLAG_PHONE  \
# count  438557.000000    438557.0    438557.000000  438557.000000
# mean    60563.675328         1.0         0.206133       0.287771
# std    138767.799647         0.0         0.404527       0.452724
# min    -17531.000000         1.0         0.000000       0.000000
# ...

# %%
dataFrame.dtypes
# Out:
# ID                       int64
# CODE_GENDER             object
# FLAG_OWN_CAR            object
# FLAG_OWN_REALTY         object
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE        object
# NAME_EDUCATION_TYPE     object
# NAME_FAMILY_STATUS      object
# NAME_HOUSING_TYPE       object
# DAYS_BIRTH               int64
# DAYS_EMPLOYED            int64
# FLAG_MOBIL               int64
# FLAG_WORK_PHONE          int64
# FLAG_PHONE               int64
# FLAG_EMAIL               int64
# OCCUPATION_TYPE         object
# CNT_FAM_MEMBERS        float64
# dtype: object

# %% [markdown]
# So far we learned we have 18 columns with ıd column and 428,557 rows of data in the costumer informations(dataframe). In the credit record data(dataframe2) there are 1,048,575 rows and 2 columns of information(MONTHS_BALANCE and STATUS). There are repeating ID's in the credit record. It shows the costumers credit history by months. We have to do calculations based on the credit record to discover costumer behaviour on paying the debts.
#
# In the application record we have a lot of categorical columns. Some problems in the dataframes are, missing values in OCCUPATION_TYPE, FLAG_MOBIL all rows are 1 meaning all the costumers have mobile phone. After dropping these columns and checking the correlation between columns we could guess that there is a multicollinearity with family size and number of children. We will do a varience importance factor calculations after processing the data.

# %% [markdown]
# # EDA and Data Processing

# %%
dataFrame=dataFrame.drop("OCCUPATION_TYPE",axis=1)
#lots of missing values
dataFrame=dataFrame.drop("FLAG_MOBIL",axis=1)
#All have mobile

# %%
from sklearn import preprocessing

# %%
Df1=dataFrame[['CODE_GENDER','FLAG_OWN_CAR','FLAG_OWN_REALTY',"NAME_INCOME_TYPE",'NAME_EDUCATION_TYPE','NAME_FAMILY_STATUS','NAME_HOUSING_TYPE']]

# %%
df1 = Df1.apply(preprocessing.LabelEncoder().fit_transform)

# %%
df1
# Out:
#         CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  NAME_INCOME_TYPE  \
# 0                 1             1                1                 4
# 1                 1             1                1                 4
# 2                 1             1                1                 4
# 3                 0             0                1                 0
# 4                 0             0                1                 0
# ...             ...           ...              ...               ...
# 438552            1             0                1                 1
# 438553            0             0                0                 4
# 438554            0             0                0                 0
# 438555            0             0                1                 1
# 438556            0             0                1                 4
#
#         NAME_EDUCATION_TYPE  NAME_FAMILY_STATUS  NAME_HOUSING_TYPE
# 0                         1                   0                  4
# ...

# %%
df1_1 =dataFrame[["ID","CNT_CHILDREN","AMT_INCOME_TOTAL","DAYS_BIRTH","DAYS_EMPLOYED","FLAG_WORK_PHONE","FLAG_PHONE","FLAG_EMAIL","CNT_FAM_MEMBERS"]]

# %%
df1_1
# Out:
#              ID  CNT_CHILDREN  AMT_INCOME_TOTAL  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0       5008804             0          427500.0      -12005          -4542
# 1       5008805             0          427500.0      -12005          -4542
# 2       5008806             0          112500.0      -21474          -1134
# 3       5008808             0          270000.0      -19110          -3051
# 4       5008809             0          270000.0      -19110          -3051
# ...         ...           ...               ...         ...            ...
# 438552  6840104             0          135000.0      -22717         365243
# 438553  6840222             0          103500.0      -15939          -3007
# 438554  6841878             0           54000.0       -8169           -372
# 438555  6842765             0           72000.0      -21673         365243
# 438556  6842885             0          121500.0      -18858          -1201
#
#         FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  CNT_FAM_MEMBERS
# ...

# %%
df1_1.dtypes
# Out:
# ID                    int64
# CNT_CHILDREN          int64
# AMT_INCOME_TOTAL    float64
# DAYS_BIRTH            int64
# DAYS_EMPLOYED         int64
# FLAG_WORK_PHONE       int64
# FLAG_PHONE            int64
# FLAG_EMAIL            int64
# CNT_FAM_MEMBERS     float64
# dtype: object

# %%
df1.dtypes
# Out:
# CODE_GENDER            int64
# FLAG_OWN_CAR           int64
# FLAG_OWN_REALTY        int64
# NAME_INCOME_TYPE       int64
# NAME_EDUCATION_TYPE    int64
# NAME_FAMILY_STATUS     int64
# NAME_HOUSING_TYPE      int64
# dtype: object

# %%
# Remove rows with NaN values in the specific columns
df1_1.dropna(subset=['AMT_INCOME_TOTAL', 'CNT_FAM_MEMBERS'], inplace=True)
# Out:
# <ipython-input-104-4192179dd8ba>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_1.dropna(subset=['AMT_INCOME_TOTAL', 'CNT_FAM_MEMBERS'], inplace=True)

# %%
df1_1['AMT_INCOME_TOTAL'] = df1_1['AMT_INCOME_TOTAL'].astype(np.int64)
df1_1['CNT_FAM_MEMBERS'] = df1_1['CNT_FAM_MEMBERS'].astype(np.int64)
# Out:
# <ipython-input-105-6093bfff1d8f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_1['AMT_INCOME_TOTAL'] = df1_1['AMT_INCOME_TOTAL'].astype(np.int64)
# <ipython-input-105-6093bfff1d8f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_1['CNT_FAM_MEMBERS'] = df1_1['CNT_FAM_MEMBERS'].astype(np.int64)

# %%
df1_1.dtypes
# Out:
# ID                  int64
# CNT_CHILDREN        int64
# AMT_INCOME_TOTAL    int64
# DAYS_BIRTH          int64
# DAYS_EMPLOYED       int64
# FLAG_WORK_PHONE     int64
# FLAG_PHONE          int64
# FLAG_EMAIL          int64
# CNT_FAM_MEMBERS     int64
# dtype: object

# %%
df=pd.concat([df1_1,df1],axis=1)

# %%
df
# Out:
#              ID  CNT_CHILDREN  AMT_INCOME_TOTAL  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0       5008804             0            427500      -12005          -4542
# 1       5008805             0            427500      -12005          -4542
# 2       5008806             0            112500      -21474          -1134
# 3       5008808             0            270000      -19110          -3051
# 4       5008809             0            270000      -19110          -3051
# ...         ...           ...               ...         ...            ...
# 438552  6840104             0            135000      -22717         365243
# 438553  6840222             0            103500      -15939          -3007
# 438554  6841878             0             54000       -8169           -372
# 438555  6842765             0             72000      -21673         365243
# 438556  6842885             0            121500      -18858          -1201
#
# ...

# %%
df.loc[df['CNT_CHILDREN'] == 19]
# Out:
#             ID  CNT_CHILDREN  AMT_INCOME_TOTAL  DAYS_BIRTH  DAYS_EMPLOYED  \
# 36388  5105054            19            112500      -11057          -1853
#
#        FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  CNT_FAM_MEMBERS  CODE_GENDER  \
# 36388                1           1           0               20            0
#
#        FLAG_OWN_CAR  FLAG_OWN_REALTY  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# 36388             0                1                 4                    4
#
#        NAME_FAMILY_STATUS  NAME_HOUSING_TYPE
# 36388                   3                  1

# %%
df.loc[df['DAYS_EMPLOYED'] == 365243]
# Out:
#              ID  CNT_CHILDREN  AMT_INCOME_TOTAL  DAYS_BIRTH  DAYS_EMPLOYED  \
# 7       5008812             0            283500      -22464         365243
# 8       5008813             0            283500      -22464         365243
# 9       5008814             0            283500      -22464         365243
# 76      5008884             0            315000      -20186         365243
# 160     5008974             0            112500      -22319         365243
# ...         ...           ...               ...         ...            ...
# 438549  6840098             0            135000      -22717         365243
# 438550  6840100             0            135000      -22717         365243
# 438551  6840102             0            135000      -22717         365243
# 438552  6840104             0            135000      -22717         365243
# 438555  6842765             0             72000      -21673         365243
#
# ...

# %%
df["CNT_CHILDREN"].plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,11))
sbn.displot(df["DAYS_EMPLOYED"])

# %%
df.sort_values("CNT_CHILDREN",ascending=False).head(22)
#drop rows with more than 6 children
# Out:
#              ID  CNT_CHILDREN  AMT_INCOME_TOTAL  DAYS_BIRTH  DAYS_EMPLOYED  \
# 36388   5105054            19            112500      -11057          -1853
# 20442   5061210            14            225000      -17754          -1689
# 20443   5061211            14            225000      -17754          -1689
# 20441   5061207            14            225000      -17754          -1689
# 208912  5931571            12            337500      -14093          -2710
# 208909  5931568            12            337500      -14093          -2710
# 208910  5931569            12            337500      -14093          -2710
# 208911  5931570            12            337500      -14093          -2710
# 435253  5372463             9            270000      -14718          -5011
# 79645   5307273             9            270000      -14718          -5011
# 79646   5307274             9            270000      -14718          -5011
# ...

# %%
df.describe()
# Out:
#                  ID   CNT_CHILDREN  AMT_INCOME_TOTAL     DAYS_BIRTH  \
# count  4.385570e+05  438557.000000      4.385570e+05  438557.000000
# mean   6.022176e+06       0.427390      1.875243e+05  -15997.904649
# std    5.716370e+05       0.724882      1.100869e+05    4185.030007
# min    5.008804e+06       0.000000      2.610000e+04  -25201.000000
# 25%    5.609375e+06       0.000000      1.215000e+05  -19483.000000
# 50%    6.047745e+06       0.000000      1.607800e+05  -15630.000000
# 75%    6.456971e+06       1.000000      2.250000e+05  -12514.000000
# max    7.999952e+06      19.000000      6.750000e+06   -7489.000000
#
#        DAYS_EMPLOYED  FLAG_WORK_PHONE     FLAG_PHONE     FLAG_EMAIL  \
# count  438557.000000    438557.000000  438557.000000  438557.000000
# mean    60563.675328         0.206133       0.287771       0.108207
# std    138767.799647         0.404527       0.452724       0.310642
# min    -17531.000000         0.000000       0.000000       0.000000
# ...

# %%
df=df[df["CNT_CHILDREN"]<=6]

# %%
df.describe()
# Out:
#                  ID   CNT_CHILDREN  AMT_INCOME_TOTAL     DAYS_BIRTH  \
# count  4.385350e+05  438535.000000      4.385350e+05  438535.000000
# mean   6.022185e+06       0.426917      1.875237e+05  -15997.918985
# std    5.716264e+05       0.721448      1.100875e+05    4185.111686
# min    5.008804e+06       0.000000      2.610000e+04  -25201.000000
# 25%    5.609384e+06       0.000000      1.215000e+05  -19484.000000
# 50%    6.047749e+06       0.000000      1.607800e+05  -15630.000000
# 75%    6.456970e+06       1.000000      2.250000e+05  -12513.500000
# max    7.999952e+06       6.000000      6.750000e+06   -7489.000000
#
#        DAYS_EMPLOYED  FLAG_WORK_PHONE     FLAG_PHONE     FLAG_EMAIL  \
# count  438535.000000    438535.000000  438535.000000  438535.000000
# mean    60566.835780         0.206125       0.287779       0.108213
# std    138770.562564         0.404522       0.452728       0.310649
# min    -17531.000000         0.000000       0.000000       0.000000
# ...

# %%
df['DAYS_EMPLOYED'].value_counts()[365243.000000]
# Out:
# 75329

# %%
df_normal_days_employed=df.sort_values("DAYS_EMPLOYED",ascending=True).head(363206)
#363206

# %%
df_normal_days_employed.describe()
#mean days of employed is -2623. About 7 years.
# Out:
#                  ID   CNT_CHILDREN  AMT_INCOME_TOTAL     DAYS_BIRTH  \
# count  3.632060e+05  363206.000000      3.632060e+05  363206.000000
# mean   6.022779e+06       0.506916      1.945936e+05  -14812.107198
# std    5.704865e+05       0.760310      1.141695e+05    3501.385788
# min    5.008804e+06       0.000000      2.700000e+04  -24834.000000
# 25%    5.617539e+06       0.000000      1.350000e+05  -17455.000000
# 50%    6.047772e+06       0.000000      1.800000e+05  -14580.000000
# 75%    6.448698e+06       1.000000      2.250000e+05  -11938.000000
# max    7.999952e+06       6.000000      6.750000e+06   -7489.000000
#
#        DAYS_EMPLOYED  FLAG_WORK_PHONE     FLAG_PHONE     FLAG_EMAIL  \
# count  363206.000000    363206.000000  363206.000000  363206.000000
# mean    -2623.064096         0.248875       0.286644       0.118822
# std      2399.557870         0.432362       0.452195       0.323580
# min    -17531.000000         0.000000       0.000000       0.000000
# ...

# %%
df=df.replace({'DAYS_EMPLOYED': 365243}, -abs(2623))

# %%
df.describe()
# Out:
#                  ID   CNT_CHILDREN  AMT_INCOME_TOTAL     DAYS_BIRTH  \
# count  4.385350e+05  438535.000000      4.385350e+05  438535.000000
# mean   6.022185e+06       0.426917      1.875237e+05  -15997.918985
# std    5.716264e+05       0.721448      1.100875e+05    4185.111686
# min    5.008804e+06       0.000000      2.610000e+04  -25201.000000
# 25%    5.609384e+06       0.000000      1.215000e+05  -19484.000000
# 50%    6.047749e+06       0.000000      1.607800e+05  -15630.000000
# 75%    6.456970e+06       1.000000      2.250000e+05  -12513.500000
# max    7.999952e+06       6.000000      6.750000e+06   -7489.000000
#
#        DAYS_EMPLOYED  FLAG_WORK_PHONE     FLAG_PHONE     FLAG_EMAIL  \
# count  438535.000000    438535.000000  438535.000000  438535.000000
# mean    -2623.053086         0.206125       0.287779       0.108213
# std      2183.762995         0.404522       0.452728       0.310649
# min    -17531.000000         0.000000       0.000000       0.000000
# ...

# %%
plt.figure(figsize=(12,11))
sbn.displot(df["DAYS_EMPLOYED"])
#we can guess that it is mostly younger people applied for a credit card.

# %% [markdown]
# # Labeling the "bad costumers"

# %%
dataFrame2
# Out:
#               ID  MONTHS_BALANCE STATUS
# 0        5001711               0      X
# 1        5001711              -1      0
# 2        5001711              -2      0
# 3        5001711              -3      0
# 4        5001712               0      C
# ...          ...             ...    ...
# 1048570  5150487             -25      C
# 1048571  5150487             -26      C
# 1048572  5150487             -27      C
# 1048573  5150487             -28      C
# 1048574  5150487             -29      C
#
# [1048575 rows x 3 columns]

# %%
#Costumers making 3+ months late payments labelled as bad costumers(0)
dataFrame2=dataFrame2.replace({'STATUS': "X"},  "1")
dataFrame2=dataFrame2.replace({'STATUS': "C"},  "1")
dataFrame2=dataFrame2.replace({'STATUS': "0"},  "1")
dataFrame2=dataFrame2.replace({'STATUS': "1"},  "1")
dataFrame2=dataFrame2.replace({'STATUS': "2"},  "1")
dataFrame2=dataFrame2.replace({'STATUS': "3"},  "0")
dataFrame2=dataFrame2.replace({'STATUS': "4"},  "0")
dataFrame2=dataFrame2.replace({'STATUS': "5"},  "0")
df2=dataFrame2

# %%
df2['STATUS'] = df2['STATUS'].astype(np.int64)

# %%
df2.describe()
# Out:
#                  ID  MONTHS_BALANCE        STATUS
# count  1.048575e+06    1.048575e+06  1.048575e+06
# mean   5.068286e+06   -1.913700e+01  9.978676e-01
# std    4.615058e+04    1.402350e+01  4.612887e-02
# min    5.001711e+06   -6.000000e+01  0.000000e+00
# 25%    5.023644e+06   -2.900000e+01  1.000000e+00
# 50%    5.062104e+06   -1.700000e+01  1.000000e+00
# 75%    5.113856e+06   -7.000000e+00  1.000000e+00
# max    5.150487e+06    0.000000e+00  1.000000e+00

# %%
df2=df2.drop("MONTHS_BALANCE",axis=1)

df2
# Out:
#               ID  STATUS
# 0        5001711       1
# 1        5001711       1
# 2        5001711       1
# 3        5001711       1
# 4        5001712       1
# ...          ...     ...
# 1048570  5150487       1
# 1048571  5150487       1
# 1048572  5150487       1
# 1048573  5150487       1
# 1048574  5150487       1
#
# [1048575 rows x 2 columns]

# %%
df2 = df2.value_counts(subset=['ID', 'STATUS']).unstack(fill_value=0)

# %%
df2
# Out:
# STATUS   0   1
# ID
# 5001711  0   4
# 5001712  0  19
# 5001713  0  22
# 5001714  0  15
# 5001715  0  60
# ...     ..  ..
# 5150482  0  18
# 5150483  0  18
# 5150484  0  13
# 5150485  0   2
# 5150487  0  30
#
# [45985 rows x 2 columns]

# %%
df2.describe()
# Out:
# STATUS             0             1
# count   45985.000000  45985.000000
# mean        0.048625     22.753920
# std         0.935266     15.465545
# min         0.000000      1.000000
# 25%         0.000000     10.000000
# 50%         0.000000     19.000000
# 75%         0.000000     34.000000
# max        48.000000     61.000000

# %%
#Preffer not to use numerical column names
df2.rename(columns = {0:'zero'}, inplace = True)
df2.rename(columns = {1:'one'}, inplace = True)

# %%
df2
# Out:
# STATUS   zero  one
# ID
# 5001711     0    4
# 5001712     0   19
# 5001713     0   22
# 5001714     0   15
# 5001715     0   60
# ...       ...  ...
# 5150482     0   18
# 5150483     0   18
# 5150484     0   13
# 5150485     0    2
# 5150487     0   30
#
# [45985 rows x 2 columns]

# %%
df2=df2.drop("one",axis=1)

# %%
df2['Reject_costumer'] = df2['zero'].apply(lambda x: 1 if x >= 1 else 0)
#1 = good/approved costumer, 0 = bad/declined costumer

# %%
df2.describe()
# Out:
# STATUS          zero  Reject_costumer
# count   45985.000000     45985.000000
# mean        0.048625         0.007198
# std         0.935266         0.084536
# min         0.000000         0.000000
# 25%         0.000000         0.000000
# 50%         0.000000         0.000000
# 75%         0.000000         0.000000
# max        48.000000         1.000000

# %%
df2=df2.drop("zero",axis=1)

# %%
df2
# Out:
# STATUS   Reject_costumer
# ID
# 5001711                0
# 5001712                0
# 5001713                0
# 5001714                0
# 5001715                0
# ...                  ...
# 5150482                0
# 5150483                0
# 5150484                0
# 5150485                0
# 5150487                0
#
# [45985 rows x 1 columns]

# %%
df
# Out:
#              ID  CNT_CHILDREN  AMT_INCOME_TOTAL  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0       5008804             0            427500      -12005          -4542
# 1       5008805             0            427500      -12005          -4542
# 2       5008806             0            112500      -21474          -1134
# 3       5008808             0            270000      -19110          -3051
# 4       5008809             0            270000      -19110          -3051
# ...         ...           ...               ...         ...            ...
# 438552  6840104             0            135000      -22717          -2623
# 438553  6840222             0            103500      -15939          -3007
# 438554  6841878             0             54000       -8169           -372
# 438555  6842765             0             72000      -21673          -2623
# 438556  6842885             0            121500      -18858          -1201
#
# ...

# %% [markdown]
# Modifying time datas into more pleasant time standarts. (negavite days to years)

# %%
#New age and employed time columns with years
import math
df["AGE"] = round(df["DAYS_BIRTH"] / -abs(365))
df["YEARS_EMPLOYED"] = round(df["DAYS_EMPLOYED"] / -abs(365))

# %%
df=df.drop("DAYS_EMPLOYED",axis=1)
df=df.drop("DAYS_BIRTH",axis=1)

# %%
df['AGE'] = df['AGE'].astype(np.int64)
df['YEARS_EMPLOYED'] = df['YEARS_EMPLOYED'].astype(np.int64)

# %%
#Solving the multicollinearity between family size and number of children with vif

from statsmodels.stats.outliers_influence import variance_inflation_factor


def compute_vif(considered_features):

    X = df[considered_features]
    X['intercept'] = 1

    vif = pd.DataFrame()
    vif["Variable"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif = vif[vif['Variable']!='intercept']
    return vif

# %%
considered_features = ["YEARS_EMPLOYED","AGE","CNT_FAM_MEMBERS","FLAG_EMAIL","FLAG_WORK_PHONE","CNT_CHILDREN","AMT_INCOME_TOTAL","FLAG_PHONE","CODE_GENDER","FLAG_OWN_CAR","FLAG_OWN_REALTY","NAME_INCOME_TYPE","NAME_EDUCATION_TYPE","NAME_FAMILY_STATUS","NAME_HOUSING_TYPE"]
compute_vif(considered_features).sort_values('VIF', ascending=False)
# Out:
#                Variable        VIF
# 2       CNT_FAM_MEMBERS  22.464730
# 5          CNT_CHILDREN  16.526903
# 13   NAME_FAMILY_STATUS   4.991001
# 1                   AGE   1.484811
# 8           CODE_GENDER   1.198114
# 9          FLAG_OWN_CAR   1.195224
# 4       FLAG_WORK_PHONE   1.184465
# 6      AMT_INCOME_TOTAL   1.125216
# 7            FLAG_PHONE   1.108220
# 11     NAME_INCOME_TYPE   1.107560
# 12  NAME_EDUCATION_TYPE   1.099177
# 0        YEARS_EMPLOYED   1.095318
# 14    NAME_HOUSING_TYPE   1.087960
# 10      FLAG_OWN_REALTY   1.075241
# 3            FLAG_EMAIL   1.037577

# %%
df=df.drop("CNT_FAM_MEMBERS",axis=1)
#CNT_FAM_MEMBERS column is causing multicollinearity.

# %%
considered_features = ["YEARS_EMPLOYED","AGE","FLAG_EMAIL","FLAG_WORK_PHONE","CNT_CHILDREN","AMT_INCOME_TOTAL","FLAG_PHONE","CODE_GENDER","FLAG_OWN_CAR","FLAG_OWN_REALTY","NAME_INCOME_TYPE","NAME_EDUCATION_TYPE","NAME_FAMILY_STATUS","NAME_HOUSING_TYPE"]
compute_vif(considered_features).sort_values('VIF', ascending=False)
# Out:
#                Variable       VIF
# 1                   AGE  1.470424
# 7           CODE_GENDER  1.194828
# 8          FLAG_OWN_CAR  1.190743
# 3       FLAG_WORK_PHONE  1.184450
# 4          CNT_CHILDREN  1.168836
# 5      AMT_INCOME_TOTAL  1.121786
# 6            FLAG_PHONE  1.108095
# 10     NAME_INCOME_TYPE  1.107408
# 11  NAME_EDUCATION_TYPE  1.099176
# 0        YEARS_EMPLOYED  1.094349
# 13    NAME_HOUSING_TYPE  1.086175
# 9       FLAG_OWN_REALTY  1.075154
# 12   NAME_FAMILY_STATUS  1.045149
# 2            FLAG_EMAIL  1.037569

# %%
len(df)
# Out:
# 438535

# %%
len(df2)
#A lot of data from features excel(df) will be lost
# Out:
# 45985

# %% [markdown]
# # Merging two dataframes

# %%
df_merged= df.merge(df2, how='inner', on=['ID'])

# %%
df_merged
# Out:
#             ID  CNT_CHILDREN  AMT_INCOME_TOTAL  FLAG_WORK_PHONE  FLAG_PHONE  \
# 0      5008804             0            427500                1           0
# 1      5008805             0            427500                1           0
# 2      5008806             0            112500                0           0
# 3      5008808             0            270000                0           1
# 4      5008809             0            270000                0           1
# ...        ...           ...               ...              ...         ...
# 36446  5149828             0            315000                0           0
# 36447  5149834             0            157500                0           1
# 36448  5149838             0            157500                0           1
# 36449  5150049             0            283500                0           0
# 36450  5150337             0            112500                0           0
#
# ...

# %%
df_merged.describe()
# Out:
#                  ID  CNT_CHILDREN  AMT_INCOME_TOTAL  FLAG_WORK_PHONE  \
# count  3.645100e+04  36451.000000      3.645100e+04     36451.000000
# mean   5.078225e+06      0.428328      1.866862e+05         0.225481
# std    4.187711e+04      0.724024      1.017960e+05         0.417904
# min    5.008804e+06      0.000000      2.700000e+04         0.000000
# 25%    5.042026e+06      0.000000      1.215000e+05         0.000000
# 50%    5.074614e+06      0.000000      1.575000e+05         0.000000
# 75%    5.115396e+06      1.000000      2.250000e+05         0.000000
# max    5.150487e+06      5.000000      1.575000e+06         1.000000
#
#          FLAG_PHONE    FLAG_EMAIL   CODE_GENDER  FLAG_OWN_CAR  \
# count  36451.000000  36451.000000  36451.000000  36451.000000
# mean       0.294779      0.089737      0.329867      0.379688
# std        0.455950      0.285808      0.470171      0.485316
# min        0.000000      0.000000      0.000000      0.000000
# ...

# %%
df_merged['Reject_costumer'].value_counts(normalize = True)
# Out:
# Reject_costumer
# 0    0.991715
# 1    0.008285
# Name: proportion, dtype: float64

# %%
sbn.countplot(df_merged["Reject_costumer"])
# Out:
# <Axes: ylabel='count'>

# %%
df_merged.describe()
# Out:
#                  ID  CNT_CHILDREN  AMT_INCOME_TOTAL  FLAG_WORK_PHONE  \
# count  3.645100e+04  36451.000000      3.645100e+04     36451.000000
# mean   5.078225e+06      0.428328      1.866862e+05         0.225481
# std    4.187711e+04      0.724024      1.017960e+05         0.417904
# min    5.008804e+06      0.000000      2.700000e+04         0.000000
# 25%    5.042026e+06      0.000000      1.215000e+05         0.000000
# 50%    5.074614e+06      0.000000      1.575000e+05         0.000000
# 75%    5.115396e+06      1.000000      2.250000e+05         0.000000
# max    5.150487e+06      5.000000      1.575000e+06         1.000000
#
#          FLAG_PHONE    FLAG_EMAIL   CODE_GENDER  FLAG_OWN_CAR  \
# count  36451.000000  36451.000000  36451.000000  36451.000000
# mean       0.294779      0.089737      0.329867      0.379688
# std        0.455950      0.285808      0.470171      0.485316
# min        0.000000      0.000000      0.000000      0.000000
# ...

# %%
df_merged["ID"].nunique()
# Out:
# 36451

# %%
df_merged=df_merged.drop("ID",axis=1)

# %% [markdown]
# # Train-Test Split

# %%
y=df_merged["Reject_costumer"].values
x=df_merged.drop("Reject_costumer",axis=1).values

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import metrics
from sklearn.metrics import f1_score

# %% [markdown]
# # Classifier Algorithms
# Will try resampling methods because the data is highly imbalanced.

# %% [markdown]
# 1-DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DT_model = DecisionTreeClassifier(class_weight="balanced",max_depth=500,min_samples_split=22)

# %%
DT_model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=500,
#                        min_samples_split=22)

# %%
y_pred = DT_model.predict(x_test)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[10434,   410],
#        [   52,    40]])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     10844
#            1       0.09      0.43      0.15        92
#
#     accuracy                           0.96     10936
#    macro avg       0.54      0.70      0.56     10936
# weighted avg       0.99      0.96      0.97     10936

# %%
y_pred_proba = DT_model.predict_proba(x_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# 1.1-DecisionTreeClassifier with random over sampling

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
from collections import Counter

# %%
ros= RandomOverSampler()

# %%
x_train_ros, y_train_ros= ros.fit_resample(x_train, y_train)

# %%
print(sorted(Counter(y_train_ros).items()))
# Out:
# [(0, 25305), (1, 25305)]

# %%
DT_1_model = DecisionTreeClassifier(class_weight="balanced",max_depth=500,min_samples_split=22)

# %%
DT_1_model.fit(x_train_ros, y_train_ros)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=500,
#                        min_samples_split=22)

# %%
y_pred_dt = DT_1_model.predict(x_test)

# %%
confusion_matrix(y_test, y_pred_dt)
# Out:
# array([[10681,   163],
#        [   56,    36]])

# %%
y_pred_proba = DT_1_model.predict_proba(x_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_dt)
auc = metrics.roc_auc_score(y_test, y_pred_dt)

#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %%
print(classification_report(y_test,y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99     10844
#            1       0.18      0.39      0.25        92
#
#     accuracy                           0.98     10936
#    macro avg       0.59      0.69      0.62     10936
# weighted avg       0.99      0.98      0.98     10936

# %% [markdown]
# 1.2-randomforest with undersampling

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
rus=RandomUnderSampler()

# %%
x_train_rus, y_train_rus= rus.fit_resample(x_train, y_train)

# %%
rf=RandomForestClassifier()

# %%
model_rf=rf.fit(x_train_rus, y_train_rus)

# %%
pred_rus_rf=model_rf.predict(x_test)

# %%
confusion_matrix(y_test, pred_rus_rf)
# Out:
# array([[7187, 3657],
#        [  30,   62]])

# %%
print(classification_report(y_test,pred_rus_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.66      0.80     10844
#            1       0.02      0.67      0.03        92
#
#     accuracy                           0.66     10936
#    macro avg       0.51      0.67      0.41     10936
# weighted avg       0.99      0.66      0.79     10936

# %%
y_pred_proba = model_rf.predict_proba(x_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  pred_rus_rf)
auc = metrics.roc_auc_score(y_test, pred_rus_rf)

#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # Conclusion
# Randomforest with undersampling gives the best result to find the minority data. With recall value of 0.67 for finding the rejected costumers it is the highest one that in this project. If the bank's aim is to find who to reject this model can be used. However if the cost of incorrectly rejecting the costumer is too high other methods can be used. As an example Decision Tree Classifier without resampling has higher accuracy rates. Because of the imbalanced nature of the data it supports to accept more costumer's credit card applications. With this model there will be more costumers getting accepted for credit card while with randomforest with undersampling there will be more correctly rejected costumers. In the implementation stage these results should be considered.
